# %% [markdown]
# ## **1. Exploratory Data Analysis (EDA)**
# This part is for exploring the given datasets that understand which attributes it includes and what values it represents, following the below steps.
#
# 1. Background and Important Notes
# 2. Import Required Libraries
# 3. Upload the Datasets
# 4. Explore the datasets
# > 1) Describe the basic structures <br>
# > 2) Check the Samples
# 5. Handling Missing Values
# 6. Handling Outliers

# %% [markdown]
# ### **1) Background and Important Notes**

# %% [markdown]
# ### **2) Import Required Libraries** <br>
# Import required libraries for EDA, including `drive` from `google.colab` and `pandas`.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **3) Upload the dataset**
# Upload the datasets to the python environment.

# %%
data = pd.read_csv("/content/drive/MyDrive/IST 707 Project/0. Datasets_new/data.csv")

# %% [markdown]
# ### **4) Explore the datasets** <br>
# There are five datasets related to audio features of digital songs provided by Spotify. <br> The following table explains the basic information of each dataset.

# %% [markdown]
# ### **`data`**

# %% [markdown]
# **4-1) Data Structure**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   valence           170653 non-null  float64
#  1   year              170653 non-null  int64
#  2   acousticness      170653 non-null  float64
#  3   artists           170653 non-null  object
#  4   danceability      170653 non-null  float64
#  5   duration_ms       170653 non-null  int64
#  6   energy            170653 non-null  float64
#  7   explicit          170653 non-null  int64
#  8   id                170653 non-null  object
#  9   instrumentalness  170653 non-null  float64
#  10  key               170653 non-null  int64
#  11  liveness          170653 non-null  float64
#  12  loudness          170653 non-null  float64
#  13  mode              170653 non-null  int64
#  14  name              170653 non-null  object
#  15  popularity        170653 non-null  int64
# ...

# %% [markdown]
# **4-2) Samples**

# %%
data.head(5)
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %% [markdown]
# **4-3) Explore more detail**

# %% [markdown]
# ### **5) Handling Missing Values** <br>
# Investigate and decide how to handle the missing values to make the quality of dataset and further reserach on building algorithms.

# %% [markdown]
# **Investigate Missing Values** <Br>
# Technically, there are no missing values in all datasets.

# %%
data.isna().sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %% [markdown]
# However, the missing values would be found in further process when we look through the datasets in detail. <br>
# For example, in testdf, there are values in the genre column that have empty brackets.

# %%
data.head(3)
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz             0.878
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8             0.000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1             0.913
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
#
#                                                 name  popularity release_date  \
# ...

# %%
n = len(pd.unique(data['artists']))
n
# Out:
# 34088

# %%
n = len(pd.unique(data['artists']))
n

# %%
data['year'].describe()
# Out:
# count    170653.000000
# mean       1976.787241
# std          25.917853
# min        1921.000000
# 25%        1956.000000
# 50%        1977.000000
# 75%        1999.000000
# max        2020.000000
# Name: year, dtype: float64

# %%
import matplotlib.pyplot as plt

def get_decade(year):
    period_start = int(year/10) * 10
    return int(period_start)

data['decade'] = data['year'].apply(get_decade)

# %%
import seaborn as sns
year_df = pd.DataFrame(data.groupby('decade').size())
year_df = year_df.reset_index()
year_df
# Out:
#     decade      0
# 0     1920   5126
# 1     1930   9549
# 2     1940  15378
# 3     1950  19850
# 4     1960  19549
# 5     1970  20000
# 6     1980  19850
# 7     1990  19901
# 8     2000  19646
# 9     2010  19774
# 10    2020   2030

# %%
sns.barplot(x = 'decade', y = '0', data = year_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-35c016db4b0a> in <cell line: 1>()
# ----> 1 sns.barplot(x = 'decade', y = '0', data = year_df)
#
# /usr/local/lib/python3.9/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...

# %% [markdown]
# These missing values will be handled in the data processing and modeling part later.

# %% [markdown]
# ### **6) Handling Handling Outliers** <br>
# Check statistical summary and find whether there are outliers in each dataset. <br>
# The outliers may interfere with making a good performance of all algorithms.

# %% [markdown]
# **`data`** <br>

# %%
import numpy as np
np.percentile(data['instrumentalness'], 1)
# Out:
# 0.0

# %%
data.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# ...

# %%
data.boxplot(figsize = (20, 5))
# Out:
# <Axes: >

# %% [markdown]
# artisits
# genres
# year
# testdf

# %% [markdown]
# **`artists`**

# %%
artists.describe()
# Out:
#                mode         count  acousticness  danceability   duration_ms  \
# count  28680.000000  28680.000000  28680.000000  28680.000000  2.868000e+04
# mean       0.759170     13.847211      0.498373      0.546490  2.388780e+05
# std        0.427595     53.372544      0.370614      0.176474  1.211318e+05
# min        0.000000      1.000000      0.000000      0.000000  1.879550e+04
# 25%        1.000000      2.000000      0.122296      0.431000  1.823304e+05
# 50%        1.000000      3.000000      0.478458      0.557000  2.186400e+05
# 75%        1.000000      8.000000      0.896000      0.675000  2.684670e+05
# max        1.000000   3169.000000      0.996000      0.986000  5.403500e+06
#
#              energy  instrumentalness      liveness      loudness  \
# count  28680.000000      28680.000000  28680.000000  28680.000000
# mean       0.497488          0.174756      0.202441    -11.140498
# std        0.254885          0.298406      0.140884      5.771749
# ...

# %%
artists.boxplot(figsize = (20, 5))
# Out:
# <Axes: >

# %% [markdown]
# **`genres`**

# %%
genres.describe()
# Out:
#               mode  acousticness  danceability   duration_ms       energy  \
# count  2973.000000   2973.000000   2973.000000  2.973000e+03  2973.000000
# mean      0.833165      0.401241      0.537187  2.517209e+05     0.561143
# std       0.372891      0.319760      0.150668  9.465686e+04     0.234486
# min       0.000000      0.000003      0.056900  3.094600e+04     0.001002
# 25%       1.000000      0.119050      0.441202  2.063788e+05     0.395058
# 50%       1.000000      0.321745      0.546496  2.375453e+05     0.601195
# 75%       1.000000      0.673991      0.647500  2.772720e+05     0.730127
# max       1.000000      0.996000      0.929000  2.382587e+06     0.994667
#
#        instrumentalness     liveness     loudness  speechiness        tempo  \
# count       2973.000000  2973.000000  2973.000000  2973.000000  2973.000000
# mean           0.211366     0.192800   -10.509848     0.083588   119.018723
# ...

# %%
genres.boxplot(figsize = (20, 5))
# Out:
# <Axes: >

# %% [markdown]
# **`year`**

# %%
year.describe()
# Out:
#         mode         year  acousticness  danceability    duration_ms  \
# count  100.0   100.000000    100.000000    100.000000     100.000000
# mean     1.0  1970.500000      0.556317      0.536783  227296.752234
# std      0.0    29.011492      0.275358      0.052356   25630.048065
# min      1.0  1921.000000      0.219931      0.414445  156881.657475
# 25%      1.0  1945.750000      0.289516      0.500800  210889.193536
# 50%      1.0  1970.500000      0.459190      0.540976  235520.850833
# 75%      1.0  1995.250000      0.856711      0.570948  247702.738058
# max      1.0  2020.000000      0.962607      0.692904  267677.823086
#
#            energy  instrumentalness    liveness    loudness  speechiness  \
# count  100.000000        100.000000  100.000000  100.000000   100.000000
# mean     0.452705          0.193582    0.208224  -11.969054     0.105861
# std      0.161738          0.122488    0.017903    3.105610     0.082128
# ...

# %%
year.boxplot(figsize = (20, 5))
# Out:
# <Axes: >

# %% [markdown]
# **`testdf`**

# %%
testdf.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  28680.000000  28680.000000  2.868000e+04  28680.000000
# mean       0.498373      0.546490  2.388780e+05      0.497488
# std        0.370614      0.176474  1.211318e+05      0.254885
# min        0.000000      0.000000  1.879550e+04      0.000000
# 25%        0.122296      0.431000  1.823304e+05      0.283568
# 50%        0.478458      0.557000  2.186400e+05      0.504000
# 75%        0.896000      0.675000  2.684670e+05      0.702783
# max        0.996000      0.986000  5.403500e+06      1.000000
#
#        instrumentalness      liveness      loudness   speechiness  \
# count      28680.000000  28680.000000  28680.000000  28680.000000
# mean           0.174756      0.202441    -11.140498      0.094014
# std            0.298406      0.140884      5.771749      0.111986
# min            0.000000      0.000000    -60.000000      0.000000
# 25%            0.000004      0.110362    -13.972292      0.039200
# ...

# %%
testdf.boxplot(figsize = (20, 5))
# Out:
# <Axes: >

# %% [markdown]
# The values of some attributes (`duration_ms`, `popularity`, etc) in all attribute are not in the same scale with other attributes. <br>
# - Especially, the `duration_ms` attribute has extreme outliers, so these values will be replaced in the same scale for further modeling.
